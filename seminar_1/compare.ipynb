# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Загрузим результаты, полученные при исходных настройках

# %%
theor_theta = np.load(rf"result\array\01_theor_theta.npy")
theor_omega = np.load(rf"result\array\02_theor_omega.npy")

default_pybullet_theta = np.load(rf"result\array\03_default_pybullet_theta.npy")
default_pybullet_omega = np.load(rf"result\array\04_default_pybullet_omega.npy")

# %%
plt.plot(theor_theta, label= "theor_theta")
plt.plot(default_pybullet_theta, label="default_pybullet_theta")
plt.legend()
plt.show()

# %%
plt.plot(theor_omega, label= "theor_omega")
plt.plot(default_pybullet_omega, label="default_pybullet_omega")
plt.legend()
plt.show()

# %% [markdown]
# ### Исправлена длина нити математического маятника на 0.5, как в теоретическом примере

# %%
fixed_pybullet_theta = np.load(rf"result\array\05_fixed_pybullet_theta.npy")
fixed_pybullet_omega = np.load(rf"result\array\06_fixed_pybullet_omega.npy")

# %%
plt.plot(theor_theta, label= "theor_theta")
plt.plot(fixed_pybullet_theta, label="fixed_pybullet_theta", linewidth=0.7)
plt.legend()
plt.show()

# %%
plt.plot(theor_omega, label= "theor_omega")
plt.plot(fixed_pybullet_omega, label="fixed_pybullet_omega", linewidth=0.7)
plt.legend()
plt.show()

# %% [markdown]
# Сравнение пропорционального регулятора с target velocity = -10 / 0.5 * sin(theta0) c теоретическим примером

# %%
pybullet_theta_velocity_control = np.load(rf"result\array\07_pybullet_theta_velocity_control.npy")
pybullet_omega_velocity_control = np.load(rf"result\array\08_pybullet_omega_velocity_control.npy")

# %%
plt.plot(theor_theta, label= "theor_theta")
plt.plot(fixed_pybullet_theta, label="fixed_pybullet_theta", linewidth=0.7)
plt.legend()
plt.show()

# %%
plt.plot(theor_omega, label= "theor_omega")
plt.plot(fixed_pybullet_omega, label="fixed_pybullet_omega", linewidth=0.7)
plt.legend()
plt.show()
